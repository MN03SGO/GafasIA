# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.8 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xuve7GMtFWGm0e9GILUL")
project = rf.workspace("proyecto-rkmc5").project("rasvision-super-final-v3-syagj")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 134.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to RasVision-Super-FINAL-V3-4 in yolov8:: 100%|██████████| 19492/19492 [00:04<00:00, 4115.55it/s]
# ...

# %%
from ultralytics import YOLO
import os

# Cargar el modelo base pre-entrenado en COCO (nuestro punto de partida)
model = YOLO('yolov8n.pt')

# La ruta al archivo de configuración de tu dataset v4.
# Asegúrate de que dataset.location exista antes de continuar
if 'dataset' in locals() and hasattr(dataset, 'location'):
    data_yaml_path = os.path.join(dataset.location, 'data.yaml')
    if os.path.exists(data_yaml_path):

        # ¡Iniciar el entrenamiento v4!
        # Mantenemos 85 épocas y paciencia 20
        results = model.train(
            data=data_yaml_path,
            epochs=85,
            imgsz=640,
            patience=20,
            name='RasVision_Supermodelo_v4' # Nuevo nombre
        )
    else:
         print(f"Error: No se encontró el archivo {data_yaml_path}. Verifica la descarga en la Celda 2.")
else:
    print("Error: La variable 'dataset' no está definida o no tiene 'location'. Ejecuta la Celda 2 primero.")
# Out:
# ...
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
